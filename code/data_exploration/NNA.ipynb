dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14311 (14K) [application/zip]
# Saving to: ‘bike_data.zip.1’
#
# bike_data.zip.1     100%[===================>]  13.98K  --.-KB/s    in 0s
#
# 2020-06-25 22:39:29 (302 MB/s) - ‘bike_data.zip.1’ saved [14311/14311]

# %%
# !unzip bike_data.zip
# Out:
# Archive:  bike_data.zip
#   inflating: points.csv
#   inflating: stations.csv

# %%
import pandas as pd
import geopandas as gpd 
import matplotlib.pyplot as plt
import folium 
from shapely.ops import nearest_points
from shapely.geometry import LineString

# %%
import imp
import unique_devices
imp.reload(unique_devices)
# Out:
# <module 'unique_devices' from '/home/ubuntu/ubermedia/code/data_exploration/unique_devices.py'>

# %%
stations = pd.read_csv("stations.csv")
stations.head()
# Out:
#    id                        name  dpcapacity     xcoord     ycoord
# 0   5      State St & Harrison St          19 -87.627739  41.873958
# 1  13  Wilton Ave & Diversey Pkwy          19 -87.652681  41.932500
# 2  14         Morgan St & 18th St          15 -87.651073  41.858086
# 3  15        Racine Ave & 19th St          15 -87.656471  41.856453
# 4  16         Wood St & North Ave          15 -87.672516  41.910329

# %%
#device_locations = unique_devices.single_device_tracking('../../')
device_locations = unique_devices.all_device_tracking('../../')

# %%
points = pd.read_csv("points.csv")
points.head()
# Out:
#    id     xcoord     ycoord
# 0   1 -87.675992  41.969792
# 1   2 -87.676702  41.956395
# 2   3 -87.601501  41.805379
# 3   4 -87.616656  41.858263
# 4   5 -87.706869  41.963010

# %%
def create_gdf(df, x="xcoord", y="ycoord"):
    return gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df[x], df[y]), crs={"init":"epsg:4326"})

# %%
stations_gdf = create_gdf(stations)
points_gdf = create_gdf(points)
# Out:
# /home/ubuntu/ubermedia/env/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
device_locations_gdf = create_gdf(device_locations, x='latitude', y='longitude')

# %%
device_locations
# Out:
#             date                                        ?1  \
# 0       20200320  4b4477755afa5cc8fbb441dd036654ff4f1769b3
# 1       20200320  4b4477755afa5cc8fbb441dd036654ff4f1769b3
# 2       20200320  4b4477755afa5cc8fbb441dd036654ff4f1769b3
# 3       20200320  4b4477755afa5cc8fbb441dd036654ff4f1769b3
# 4       20200320  56eb9fcc3594d7e4cdf8ab89ba3e966bcffe33e8
# ...          ...                                       ...
# 301225  20200320  f92dbcf733cbe2ac373ffd8bcc71dfe5b8bc3c0d
# 301226  20200320  cb031fa33be3f70020d937cd30b075590cdedf7c
# 301227  20200320  cb031fa33be3f70020d937cd30b075590cdedf7c
# 301228  20200320  9faaaf6c25725e4e650e17a97b8f446106b6f7c3
# 301229  20200320  9faaaf6c25725e4e650e17a97b8f446106b6f7c3
#
#                                               ?2   latitude   longitude  \
# 0       690b67e58b814880b039af8a26fcaf335cee6c2e -32.940111  151.763809
# 1       690b67e58b814880b039af8a26fcaf335cee6c2e -32.940122  151.763809
# 2       33f401d55ef0b61b8778b82d506cadb2db23e693 -32.935260  151.768780
# 3       eee84a6dbffa251186c88bd3ea91d466f596ae77 -32.934457  151.767559
# 4       a6407b874c33187430e5a286bb4519bc1cadf490 -32.787831  151.728532
# ...                                          ...        ...         ...
# 301225  d857642d3e4ed0b4165df04d0bf2d0ca942d3c59 -33.021914  151.661542
# 301226  d97ad03b30f726139aff956eabb5f12b0881648f -32.814121  151.635773
# 301227  c44d9baa538129a7ef4e32e38e128db60818269f -32.794728  151.635639
# 301228  cd9d82370a062e0784c324c3cde68de08aa8cb3a -32.919672  151.747597
# 301229  cd9d82370a062e0784c324c3cde68de08aa8cb3a -32.919672  151.747597
#
#          device_id
# 0       1584696510
# 1       1584696525
# 2       1584696184
# 3       1584702792
# 4       1584664562
# ...            ...
# 301225  1584670979
# 301226  1584663908
# 301227  1584663684
# 301228  1584743671
# 301229  1584743671
#
# [301230 rows x 6 columns]

# %%
m = folium.Map([device_locations.iloc[0]['latitude'], device_locations.iloc[0]['longitude']],
               zoom_start=10,
               tiles="CartoDb dark_matter")
locs_devices = zip(device_locations_gdf.latitude, device_locations_gdf.longitude)
for location in locs_devices:
    folium.CircleMarker(location=location, color="red", radius=4).add_to(m)
m.save("map3.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([41.805379, -87.601501],
               zoom_start=12,
               tiles="CartoDb dark_matter")
locs_stations = zip(stations_gdf.ycoord, stations_gdf.xcoord)
locs_points = zip(points_gdf.ycoord, points_gdf.xcoord)
for location in locs_stations:
    folium.CircleMarker(location=location, color="red", radius=4).add_to(m)
for location in locs_points:
    folium.CircleMarker(location=location, color="white", radius=2).add_to(m)
m.save("map1.html")
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-475f223e90d6> in <module>
# ----> 1 m = folium.Map([41.805379, -87.601501],
#       2                zoom_start=12,
#       3                tiles="CartoDb dark_matter")
#       4 locs_stations = zip(stations_gdf.ycoord, stations_gdf.xcoord)
#       5 locs_points = zip(points_gdf.ycoord, points_gdf.xcoord)
#
# NameError: name 'folium' is not defined

# %%
device_locations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec66d52edb24> in <module>
# ----> 1 device_locations
#
# NameError: name 'device_locations' is not defined

# %%
def calculate_nearest(row, destination, val, col="geometry"):
    dest_unary = destination["geometry"].unary_union
    nearest_geom = nearest_points(row[col], dest_unary)
    match_geom = destination.loc[destination.geometry == nearest_geom[1]]
    match_value = match_geom[val].to_numpy()[0]
    return match_value

# %%
points_gdf["nearest_geom"] = points_gdf.apply(calculate_nearest, destination=stations_gdf, val="geometry", axis=1)

# %%
points_gdf["nearest_station"] = points_gdf.apply(calculate_nearest, destination=stations_gdf, val="name", axis=1)

# %%
points_gdf.head()
# Out:
#    id     xcoord     ycoord                    geometry  \
# 0   1 -87.675992  41.969792  POINT (-87.67599 41.96979)
# 1   2 -87.676702  41.956395  POINT (-87.67670 41.95640)
# 2   3 -87.601501  41.805379  POINT (-87.60150 41.80538)
# 3   4 -87.616656  41.858263  POINT (-87.61666 41.85826)
# 4   5 -87.706869  41.963010  POINT (-87.70687 41.96301)
#
#                            nearest_geom                 nearest_station
# 0   POINT (-87.67423700000001 41.96909)   Ravenswood Ave & Lawrence Ave
# 1          POINT (-87.679259 41.955927)  Lincoln Ave & Belle Plaine Ave
# 2  POINT (-87.59938299999999 41.809835)         Greenwood Ave & 47th St
# 3          POINT (-87.619407 41.857611)           Calumet Ave & 18th St
# 4  POINT (-87.68848699999999 41.966555)        Western Ave & Leland Ave

# %%
points_gdf['line'] = points_gdf.apply(lambda row: LineString([row['geometry'], row['nearest_geom']]), axis=1)
points_gdf.head()
# Out:
#    id     xcoord     ycoord                    geometry  \
# 0   1 -87.675992  41.969792  POINT (-87.67599 41.96979)
# 1   2 -87.676702  41.956395  POINT (-87.67670 41.95640)
# 2   3 -87.601501  41.805379  POINT (-87.60150 41.80538)
# 3   4 -87.616656  41.858263  POINT (-87.61666 41.85826)
# 4   5 -87.706869  41.963010  POINT (-87.70687 41.96301)
#
#                            nearest_geom                 nearest_station  \
# 0   POINT (-87.67423700000001 41.96909)   Ravenswood Ave & Lawrence Ave
# 1          POINT (-87.679259 41.955927)  Lincoln Ave & Belle Plaine Ave
# 2  POINT (-87.59938299999999 41.809835)         Greenwood Ave & 47th St
# 3          POINT (-87.619407 41.857611)           Calumet Ave & 18th St
# 4  POINT (-87.68848699999999 41.966555)        Western Ave & Leland Ave
#
#                                                 line
# 0  LINESTRING (-87.67599211881929 41.969792417635...
# 1  LINESTRING (-87.6767023973826 41.9563952204838...
# 2  LINESTRING (-87.601501134953 41.8053785205414,...
# 3  LINESTRING (-87.61665568206151 41.858262512299...
# 4  LINESTRING (-87.7068694739994 41.9630104417897...

# %%
line_gdf = points_gdf[["id", "nearest_station", "line"]].set_geometry('line')

# %%
line_gdf.crs = crs={"init":"epsg:4326"}
# Out:
# /home/ubuntu/ubermedia/env/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
points_gdf.drop(["nearest_geom", "line"], axis=1, inplace=True)
points_gdf.head()
# Out:
#    id     xcoord     ycoord                    geometry  \
# 0   1 -87.675992  41.969792  POINT (-87.67599 41.96979)
# 1   2 -87.676702  41.956395  POINT (-87.67670 41.95640)
# 2   3 -87.601501  41.805379  POINT (-87.60150 41.80538)
# 3   4 -87.616656  41.858263  POINT (-87.61666 41.85826)
# 4   5 -87.706869  41.963010  POINT (-87.70687 41.96301)
#
#                   nearest_station
# 0   Ravenswood Ave & Lawrence Ave
# 1  Lincoln Ave & Belle Plaine Ave
# 2         Greenwood Ave & 47th St
# 3           Calumet Ave & 18th St
# 4        Western Ave & Leland Ave

# %%
m = folium.Map([41.805379, -87.601501],
               zoom_start = 12, 
               tiles="CartoDb dark_matter")
locs_stations = zip(stations_gdf.ycoord, stations_gdf.xcoord)
locs_points = zip(points_gdf.ycoord, points_gdf.xcoord)
for location in locs_stations:
    folium.CircleMarker(location=location, color="red", radius=8).add_to(m)
for location in locs_points:
    folium.CircleMarker(location=location, color="white", radius=4).add_to(m)
folium.GeoJson(line_gdf).add_to(m)
m.save("map2.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # End
